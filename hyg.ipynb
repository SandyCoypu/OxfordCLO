# %%
import numpy as np
import pandas as pd
dfful = pd.read_csv('file:///home/oxclo/hyg/hygdata_v3.csv')
dfful
# Out:
#             id   hip        hd      hr         gl   bf proper         ra  \
# 0            0   NaN       NaN     NaN        NaN  NaN    Sol   0.000000
# 1            1   1.0  224700.0     NaN        NaN  NaN    NaN   0.000060
# 2            2   2.0  224690.0     NaN        NaN  NaN    NaN   0.000283
# 3            3   3.0  224699.0     NaN        NaN  NaN    NaN   0.000335
# 4            4   4.0  224707.0     NaN        NaN  NaN    NaN   0.000569
# 5            5   5.0  224705.0     NaN        NaN  NaN    NaN   0.000665
# 6            6   6.0       NaN     NaN        NaN  NaN    NaN   0.001246
# 7            7   7.0       NaN     NaN        NaN  NaN    NaN   0.001470
# 8            8   8.0  224709.0     NaN        NaN  NaN    NaN   0.001823
# 9            9   9.0  224708.0     NaN        NaN  NaN    NaN   0.002355
# 10          10  10.0  224717.0     NaN        NaN  NaN    NaN   0.002424
# 11          11  11.0  224720.0     NaN        NaN  NaN    NaN   0.002488
# ...

# %%
config IPCompleter.greedy=True

# %%
dfful.shape
# Out:
# (119614, 37)

# %%
columns = ['id','gl','mag','absmag','proper','ra','dec','dist','con','ci','lum']
df = pd.DataFrame(dfful, columns=columns)
df
# Out:
#             id         gl    mag  absmag proper         ra        dec  \
# 0            0        NaN -26.70   4.850    Sol   0.000000   0.000000
# 1            1        NaN   9.10   2.390    NaN   0.000060   1.089009
# 2            2        NaN   9.27   5.866    NaN   0.000283 -19.498840
# 3            3        NaN   6.61  -1.619    NaN   0.000335  38.859279
# 4            4        NaN   8.06   2.421    NaN   0.000569 -51.893546
# 5            5        NaN   8.55   1.494    NaN   0.000665 -40.591202
# 6            6        NaN  12.31   8.607    NaN   0.001246   3.946458
# 7            7        NaN   9.64   5.828    NaN   0.001470  20.036114
# 8            8        NaN   9.05   2.536    NaN   0.001823  25.886461
# 9            9        NaN   8.59   0.473    NaN   0.002355  36.585958
# 10          10        NaN   8.59   3.763    NaN   0.002424 -50.866976
# 11          11        NaN   7.34   0.446    NaN   0.002488  46.939997
# ...

# %%
df['proper'].dropna()
# Out:
# 0                              Sol
# 676                      Alpheratz
# 744                           Caph
# 1065                       Algenib
# 2076                         Ankaa
# 3172                        Shedir
# 3413                        Diphda
# 3759                     96 G. Psc
# 3820             Van Maanen's Star
# 4417                           Cih
# 5436                        Mirach
# 6672                       Ruchbah
# 7574                      Achernar
# 8884                      Sheratan
# 9618                        Almaak
# 9861                         Hamal
# 10800                         Mira
# 11734                      Polaris
# 12082                   268 G. Cet
# 13813                       Acamar
# 14100                       Menkar
# 14540                        Algol
# 15471                    82 G. Eri
# 15824                      Mirphak
# 17661                      Alcyone
# 18497                       Zaurak
# 21368                    Aldebaran
# ...

# %%
df.loc[df['proper'].notnull()]
# Out:
#             id         gl    mag  absmag                    proper         ra  \
# 0            0        NaN -26.70   4.850                       Sol   0.000000
# 676        676        NaN   2.07  -0.297                 Alpheratz   0.139791
# 744        744       Gl 8   2.28   1.155                      Caph   0.152887
# 1065      1065        NaN   2.83  -2.567                   Algenib   0.220598
# 2076      2076        NaN   2.40   0.327                     Ankaa   0.438056
# 3172      3172        NaN   2.24  -1.985                    Shedir   0.675116
# 3413      3413      Gl 31   2.04  -0.312                    Diphda   0.726490
# 3759      3759      Gl 33   5.74   6.378                 96 G. Psc   0.806382
# 3820      3820      Gl 35  12.37  14.222         Van Maanen's Star   0.819416
# 4417      4417        NaN   2.15  -3.981                       Cih   0.945143
# 5436      5436    Gl 53.3   2.07  -1.840                    Mirach   1.162194
# ...

# %%
df.sort_values('dist',ascending=False)
# Out:
#             id       gl    mag  absmag            proper         ra  \
# 38104    38104      NaN   8.41 -11.590               NaN   7.828196
# 56934    56934      NaN   9.07 -10.930               NaN  11.706949
# 105463  105463      NaN   9.34 -10.660               NaN  21.427510
# 51482    51482      NaN   7.51 -12.490               NaN  10.547573
# 56943    56943      NaN   9.10 -10.900               NaN  11.708783
# 56942    56942      NaN  11.43  -8.570               NaN  11.708740
# 8165      8165      NaN   8.20 -11.800               NaN   1.752545
# 105459  105459      NaN   7.60 -12.400               NaN  21.426370
# 8167      8167      NaN   9.89 -10.110               NaN   1.752777
# 56937    56937      NaN   7.31 -12.690               NaN  11.707256
# 84915    84915      NaN   8.09 -11.910               NaN  17.406474
# 84917    84917      NaN   8.09 -11.910               NaN  17.406664
# 56935    56935      NaN   8.70 -11.300               NaN  11.707042
# ...

# %%
df.head(n=10)
# Out:
#    id   gl    mag  absmag proper        ra        dec      dist  con     ci  \
# 0   0  NaN -26.70   4.850    Sol  0.000000   0.000000    0.0000  NaN  0.656
# 1   1  NaN   9.10   2.390    NaN  0.000060   1.089009  219.7802  Psc  0.482
# 2   2  NaN   9.27   5.866    NaN  0.000283 -19.498840   47.9616  Cet  0.999
# 3   3  NaN   6.61  -1.619    NaN  0.000335  38.859279  442.4779  And -0.019
# 4   4  NaN   8.06   2.421    NaN  0.000569 -51.893546  134.2282  Phe  0.370
# 5   5  NaN   8.55   1.494    NaN  0.000665 -40.591202  257.7320  Phe  0.902
# 6   6  NaN  12.31   8.607    NaN  0.001246   3.946458   55.0358  NaN  1.336
# 7   7  NaN   9.64   5.828    NaN  0.001470  20.036114   57.8704  Peg  0.740
# 8   8  NaN   9.05   2.536    NaN  0.001823  25.886461  200.8032  Peg  1.102
# 9   9  NaN   8.59   0.473    NaN  0.002355  36.585958  420.1681  And  1.067
#
#           lum
# 0    1.000000
# 1    9.638290
# 2    0.392283
# 3  386.901132
# 4    9.366989
# 5   21.998851
# 6    0.031420
# ...

# %%
df.loc[df['proper'].notnull()].sort_values('dist', ascending=False).head(n=5)
# Out:
#             id   gl    mag  absmag                    proper         ra  \
# 60731    60731  NaN  12.88  -7.120                    3C 273  12.485193
# 111893  111893  NaN   8.83 -11.170            Babcock's star  22.735418
# 95992    95992  NaN  10.00 -10.000  Campbell's Hydrogen Star  19.579231
# 26176    26176  NaN   2.75  -6.519                    Hatsya   5.590551
# 25920    25920  NaN   2.58  -6.583                     Arneb   5.545504
#
#               dec         dist  con     ci           lum
# 60731    2.052398  100000.0000  NaN  0.120  6.137620e+04
# 111893  55.589226  100000.0000  Lac  0.031  2.558586e+06
# 95992   30.516371  100000.0000  Cyg -0.013  8.709636e+05
# 26176   -5.909901     714.2857  Ori -0.210  3.528580e+04
# 25920  -17.822289     680.2721  Lep  0.211  3.742829e+04

# %%
df.loc[df['gl'].notnull()].sort_values('lum', ascending=True).head(n=3)
# Out:
#             id       gl    mag  absmag proper         ra        dec     dist  \
# 118970  118972  NN 3849  19.74  19.629    NaN  14.478657  33.176703  10.5263
# 119180  119182  NN 4029  20.10  19.237    NaN  17.833107  22.683357  14.8810
# 118570  118572  NN 3517  18.80  19.137    NaN   8.893343  -3.490080   8.5616
#
#         con  ci       lum
# 118970  NaN NaN  0.000001
# 119180  NaN NaN  0.000002
# 118570  NaN NaN  0.000002

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter(x='dist',y='lum')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.loc[df['dist']<99999].plot.scatter(x='dist', y='lum', logy=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
